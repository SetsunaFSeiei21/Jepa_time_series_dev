# %%
import os

# %%
print(os.getcwd())
# Out:
# /public/home/202411094934/python_project/Spatio-Temporal-Library/src

# %%
import numpy as np
dataset_root = "/public/home/202411094934/python_project/Spatio-Temporal-Library/data/time-series-dataset/ETTm2"
train_dataset = os.path.join(dataset_root, "train_data.npy")
train_stamp_dataset = os.path.join(dataset_root, "train_timestamps.npy")

# %%
dataset = np.load(train_dataset)
stamp_dataset = np.load(train_stamp_dataset)
print(type(dataset))
# Out:
# <class 'numpy.ndarray'>

# %%
stamp_dataset[120]
# Out:
# array([0.25      , 0.71428573, 0.03225806, 0.03225806], dtype=float32)

# %%
dataset.shape
# Out:
# (34560, 7)

# %%
dataset[0]
# Out:
# array([41.13 , 12.481, 36.536,  9.355,  4.424,  1.311, 38.662],
#       dtype=float32)
